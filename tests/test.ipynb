# %% [markdown]
# 1 md
# Introduction
#
# No need to say much, just run all the way!
#
# This script was created by Tony Is Stark, for learning purposes only, please do not misuse. If you have any questions, scroll to the end!
#
# Video tutorial: https://www.youtube.com/watch?v=MgcnGnfVDcc&list=PL4wPj6o65_XHcqBZ7iMVEaKrPi5-LrYNZ
# 1.1 code
#
# #@title Check the allocated device
# Check the device, whether it's K80 or T4, if it's K80...!
# 2. md
#
# Note:
# Initialize the project root to your own path, generally
# Google Drive path: /content/drive/MyDrive/
# Shared Google Drive path: /content/drive/Shareddrives/DriverName
# DriverName: Shared drive name, different for each person, change it according to your own situation.
#
# *Do not mess with preparing materials if you already have materials and models!!!
# 2 code
#
# #@title Mount Google Drive
#
# #@title Initialize the project
#
# #@title Prepare materials (clicking will clear the workspace)
# 3. md
# 4. md
# Step 2: Install software
# 5. md
# Step 3: Extract faces
# 5. md
# Step 4: Train the model
# 6. md
# Step 5: Convert output
# 7. md
# Step 6: Continue training
# 8. md
# Tools
# Pack materials to speed up upload, download, and loading speed.
# final
# Others
#
# QQ Group: 1129237074
#
# Google Drive link: https://drive.google.com/drive/my-drive
#
# Author's email: wpgdream@gmail.com
#
# Knowledge Planet: https://t.zsxq.com/vFuzRNr
#
# Github: https://github.com/dream80/DeepFaceLab_Colab
# If it's useful, please give it a star. Thank you!!!
